# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from lifelines import LogNormalAFTFitter, WeibullAFTFitter, LogLogisticAFTFitter
from lifelines import CoxPHFitter

# %%
# get data from s3
url = "https://s3.amazonaws.com/survival2024/hurricane.csv"
df = pd.read_csv(url)

# %%
df['flood']=0
df.loc[df['reason'] == 1, 'flood'] = 1
df_flood = df[['backup', 'age', 'bridgecrane', 'servo', 'gear', 'trashrack', 'slope', 'elevation', 'hour', 'flood']]
df_flood.head()
# Out:
#    backup  age  bridgecrane  servo  gear  trashrack  slope  elevation  hour  \
# 0       0  6.0            0      0     0          1      3          2    48
# 1       0  6.0            1      0     0          1      7          3    48
# 2       0  6.1            1      0     0          1      3          3    48
# 3       1  6.1            1      0     0          0      4          3    48
# 4       0  6.2            1      1     0          1      3          4    48
#
#    flood
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
df_flood.shape
# Out:
# (770, 10)

# %% [markdown]
# ## AFT Model

# %% [markdown]
# ### Weibull
# has the highest log-likelihood ratio test, thus is the best fit for our data

# %%
aft_Weibull = WeibullAFTFitter()
aft_Weibull.fit(df_flood, duration_col='hour', event_col='flood',ancillary=False )
aft_Weibull.print_summary()
# Out:
# <lifelines.WeibullAFTFitter: fitted with 770 total observations, 655 right-censored observations>
#              duration col = 'hour'
#                 event col = 'flood'
#    number of observations = 770
# number of events observed = 115
#            log-likelihood = -724.73
#          time fit was run = 2024-11-12 16:18:22 UTC
#
# ---
#                      coef exp(coef)  se(coef)  coef lower 95%  coef upper 95% exp(coef) lower 95% exp(coef) upper 95%
# param   covariate
# lambda_ age          0.05      1.05      0.07           -0.09            0.18                0.92                1.20
#         backup       0.25      1.28      0.12            0.00            0.49                1.00                1.63
#         bridgecrane -0.19      0.83      0.20           -0.57            0.20                0.56                1.22
#         elevation    0.05      1.05      0.08           -0.10            0.21                0.90                1.23
# ...

# %% [markdown]
# ### Log Logistic

# %%
aft_LogLogistic = LogLogisticAFTFitter()
aft_LogLogistic.fit(df_flood, duration_col='hour', event_col='flood')
aft_LogLogistic.print_summary()
# Out:
# <lifelines.LogLogisticAFTFitter: fitted with 770 total observations, 655 right-censored observations>
#              duration col = 'hour'
#                 event col = 'flood'
#    number of observations = 770
# number of events observed = 115
#            log-likelihood = -724.71
#          time fit was run = 2024-11-12 16:18:23 UTC
#
# ---
#                     coef exp(coef)  se(coef)  coef lower 95%  coef upper 95% exp(coef) lower 95% exp(coef) upper 95%
# param  covariate
# alpha_ age          0.04      1.04      0.07           -0.10            0.18                0.90                1.19
#        backup       0.25      1.29      0.13            0.00            0.51                1.00                1.66
#        bridgecrane -0.20      0.82      0.20           -0.60            0.19                0.55                1.21
#        elevation    0.05      1.05      0.08           -0.11            0.20                0.89                1.23
# ...

# %% [markdown]
# ### Log Normal

# %%
aft_LogNormalAFTFitter = LogNormalAFTFitter()
aft_LogNormalAFTFitter.fit(df_flood, duration_col='hour', event_col='flood')
aft_LogNormalAFTFitter.print_summary()
# Out:
# <lifelines.LogNormalAFTFitter: fitted with 770 total observations, 655 right-censored observations>
#              duration col = 'hour'
#                 event col = 'flood'
#    number of observations = 770
# number of events observed = 115
#            log-likelihood = -728.09
#          time fit was run = 2024-11-12 16:18:23 UTC
#
# ---
#                     coef exp(coef)  se(coef)  coef lower 95%  coef upper 95% exp(coef) lower 95% exp(coef) upper 95%
# param  covariate
# mu_    age         -0.00      1.00      0.08           -0.16            0.16                0.85                1.17
#        backup       0.31      1.36      0.15            0.02            0.60                1.02                1.82
#        bridgecrane -0.27      0.76      0.23           -0.73            0.18                0.48                1.20
#        elevation    0.01      1.01      0.09           -0.17            0.19                0.84                1.21
# ...

# %% [markdown]
# ### Feature Selection w/ Weibull.
# Backwards Selection at the alpha = 0.03 level

# %%
aft_Weibull.fit(df_flood.loc[:, df_flood.columns != 'age'], duration_col='hour', event_col='flood',ancillary=False )
aft_Weibull.fit(df_flood.loc[:, ~df_flood.columns.isin(['age', 'elevation'])], duration_col='hour', event_col='flood',ancillary=False )
aft_Weibull.fit(df_flood.loc[:, ~df_flood.columns.isin(['age', 'elevation', 'bridgecrane'])], duration_col='hour', event_col='flood',ancillary=False )
aft_Weibull.fit(df_flood.loc[:, ~df_flood.columns.isin(['age', 'elevation', 'bridgecrane', 'gear'])], duration_col='hour', event_col='flood',ancillary=False )
aft_Weibull.fit(df_flood.loc[:, ~df_flood.columns.isin(['age', 'elevation', 'bridgecrane', 'gear', 'trashrack'])], duration_col='hour', event_col='flood',ancillary=False )

aft_Weibull.print_summary()
# Out:
# <lifelines.WeibullAFTFitter: fitted with 770 total observations, 655 right-censored observations>
#              duration col = 'hour'
#                 event col = 'flood'
#    number of observations = 770
# number of events observed = 115
#            log-likelihood = -729.17
#          time fit was run = 2024-11-12 16:18:25 UTC
#
# ---
#                    coef exp(coef)  se(coef)  coef lower 95%  coef upper 95% exp(coef) lower 95% exp(coef) upper 95%
# param   covariate
# lambda_ backup     0.27      1.31      0.12            0.03            0.51                1.03                1.67
#         servo      0.39      1.47      0.13            0.13            0.64                1.14                1.90
#         slope     -0.06      0.94      0.02           -0.09           -0.03                0.91                0.97
#         Intercept  4.77    118.05      0.15            4.47            5.07               87.57              159.15
# ...

# %% [markdown]
# ## Cox regression
# The varriable `servo` fails the assumptions

# %%
cph = CoxPHFitter()
#we drop age here or else assumptions fail in the next step
cph.fit(df_flood.loc[:, df_flood.columns != 'age'], duration_col='hour', event_col='flood')
cph.print_summary()
# Out:
# <lifelines.CoxPHFitter: fitted with 770 total observations, 655 right-censored observations>
#              duration col = 'hour'
#                 event col = 'flood'
#       baseline estimation = breslow
#    number of observations = 770
# number of events observed = 115
#    partial log-likelihood = -714.57
#          time fit was run = 2024-11-12 16:18:25 UTC
#
# ---
#              coef exp(coef)  se(coef)  coef lower 95%  coef upper 95% exp(coef) lower 95% exp(coef) upper 95%
# covariate
# backup      -0.40      0.67      0.19           -0.77           -0.03                0.46                0.97
# bridgecrane  0.28      1.32      0.31           -0.33            0.88                0.72                2.41
# servo       -0.46      0.63      0.21           -0.86           -0.06                0.42                0.95
# gear        -0.62      0.54      0.38           -1.37            0.12                0.25                1.13
# ...

# %%
cph.check_assumptions(df_flood.loc[:, df_flood.columns != 'age'], p_value_threshold=0.05)#, show_plots=True)
# Out:
# The ``p_value_threshold`` is set at 0.05. Even under the null hypothesis of no violations, some
# covariates will be below the threshold by chance. This is compounded when there are many covariates.
# Similarly, when there are lots of observations, even minor deviances from the proportional hazard
# assumption will be flagged.
#
# With that in mind, it's best to use a combination of statistical tests and visual tests to determine
# the most serious violations. Produce visual plots using ``check_assumptions(..., show_plots=True)``
# and looking for non-constant lines. See link [A] below for a full example.
# <lifelines.StatisticalResult: proportional_hazard_test>
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              model = <lifelines.CoxPHFitter: fitted with 770 total observations, 655 right-censored observations>
#          test_name = proportional_hazard_test
#
# ---
#                   test_statistic    p  -log2(p)
# ...

# %%
#backwards selection at alpha 0.03
cph.fit(df_flood.loc[:, ~df_flood.columns.isin(['age', 'elevation', 'bridgecrane', 'gear', 'trashrack'])], duration_col='hour', event_col='flood')
cph.print_summary()
# Out:
# <lifelines.CoxPHFitter: fitted with 770 total observations, 655 right-censored observations>
#              duration col = 'hour'
#                 event col = 'flood'
#       baseline estimation = breslow
#    number of observations = 770
# number of events observed = 115
#    partial log-likelihood = -718.65
#          time fit was run = 2024-11-12 16:18:25 UTC
#
# ---
#            coef exp(coef)  se(coef)  coef lower 95%  coef upper 95% exp(coef) lower 95% exp(coef) upper 95%
# covariate
# backup    -0.42      0.66      0.19           -0.79           -0.05                0.45                0.95
# servo     -0.59      0.55      0.20           -0.98           -0.21                0.38                0.81
# slope      0.09      1.10      0.03            0.04            0.15                1.04                1.16
#
#            cmp to     z      p  -log2(p)
# covariate
# backup       0.00 -2.21   0.03      5.20
# servo        0.00 -3.02 <0.005      8.63
# ...

# %%
cph.check_assumptions(df_flood.loc[:, ~df_flood.columns.isin(['age', 'elevation', 'bridgecrane', 'gear', 'trashrack'])], p_value_threshold=0.05)#, show_plots=True)
# Out:
# The ``p_value_threshold`` is set at 0.05. Even under the null hypothesis of no violations, some
# covariates will be below the threshold by chance. This is compounded when there are many covariates.
# Similarly, when there are lots of observations, even minor deviances from the proportional hazard
# assumption will be flagged.
#
# With that in mind, it's best to use a combination of statistical tests and visual tests to determine
# the most serious violations. Produce visual plots using ``check_assumptions(..., show_plots=True)``
# and looking for non-constant lines. See link [A] below for a full example.
# <lifelines.StatisticalResult: proportional_hazard_test>
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              model = <lifelines.CoxPHFitter: fitted with 770 total observations, 655 right-censored observations>
#          test_name = proportional_hazard_test
#
# ---
#              test_statistic    p  -log2(p)
# backup km              0.07 0.79      0.33
# ...

# %% [markdown]
# ## Analyze the pumps that failed due to flood failure and evaluate which pumps to recommend getting an upgrade on the factors found significant by the model.
#
# - You can only perform one upgrade per pump.
# - You have a fixed budget of $2.5 million and must use this money accordingly to keep
#   pumps functioning as long as possible.
#
# Our models both found backup, servo, and slope to be the biggest causes of flood failure.
# - Slope in non-upgradeable
# - Servo costs $150K to upgrade, but has a much lower p-value
# - Backup costs $100K to upgrade

# %%
print(f"{1-df_flood[(df_flood['flood']==1)]['servo'].mean():.0%}", "of flood failures did not have a servo.")
print(f"{1-df_flood[(df_flood['flood']==1)]['backup'].mean():.0%}", "of flood failures did not have a backup.")
# Out:
# 55% of flood failures did not have a servo.
# 58% of flood failures did not have a backup.

# %% [markdown]
# ### Servo

# %%
df_historic = df_flood.loc[:, ~df_flood.columns.isin(['age', 'elevation', 'bridgecrane', 'gear', 'trashrack'])]
df_historic_fail_servo = df_historic[(df_historic['servo'] == 0) & (df_historic['flood'] == 1)]

df_historic_fail_servo_upgrade = df_historic_fail_servo.copy()
df_historic_fail_servo_upgrade['servo'] = 1

# %%
nonupgraded_servo =aft_Weibull.predict_survival_function(df_historic_fail_servo)
upgraded_servo =aft_Weibull.predict_survival_function(df_historic_fail_servo_upgrade)
survival_diff = upgraded_servo - nonupgraded_servo
#survival_diff.iloc[47,:]
servo_time_diff = survival_diff.sum().sort_values(ascending=False)
servo_time_diff_df = pd.DataFrame(servo_time_diff)
servo_time_diff_df
# Out:
#             0
# 402  6.321521
# 355  6.321521
# 403  6.321521
# 389  5.216020
# 341  4.083330
# ..        ...
# 405  1.427321
# 346  1.427321
# 383  1.427321
# 374  1.427321
# 351  1.309444
#
# [63 rows x 1 columns]

# %%
predicted_durations_0 = aft_Weibull.predict_median(df_historic_fail_servo)
median_survival_time_0 = predicted_durations_0.median()

predicted_durations_1 = aft_Weibull.predict_median(df_historic_fail_servo_upgrade)
median_survival_time_1 = predicted_durations_1.median()

# Step 3: Compare the median survival times
print("Median Survival Time (Servo = 0):", median_survival_time_0)
print("Median Survival Time (Servo = 1):", median_survival_time_1)
print("Difference in Median Survival Time:", median_survival_time_1 - median_survival_time_0)
# Out:
# Median Survival Time (Servo = 0): 77.69570034107777
# Median Survival Time (Servo = 1): 114.28349245019388
# Difference in Median Survival Time: 36.58779210911611

# %% [markdown]
# ### Backup

# %%
df_historic_fail_backup = df_historic[(df_historic['backup'] == 0) & (df_historic['flood'] == 1)]

# Create a copy for the upgraded scenario with 'backup' set to 1
df_historic_fail_backup_upgrade = df_historic_fail_backup.copy()
df_historic_fail_backup_upgrade['backup'] = 1

# %%
# Predict the survival function for the non-upgraded backup (backup = 0)
nonupgraded_backup = aft_Weibull.predict_survival_function(df_historic_fail_backup)

# Predict the survival function for the upgraded backup (backup = 1)
upgraded_backup = aft_Weibull.predict_survival_function(df_historic_fail_backup_upgrade)

# Calculate the difference between the upgraded and non-upgraded survival functions
survival_diff = upgraded_backup - nonupgraded_backup

# Sum the differences across time and sort in descending order
backup_time_diff = survival_diff.sum().sort_values(ascending=False)
backup_time_diff_df = pd.DataFrame(backup_time_diff)
backup_time_diff_df

# %%
# Predict the median survival durations for the non-upgraded backup (backup = 0)
predicted_durations_0 = aft_Weibull.predict_median(df_historic_fail_backup)
median_survival_time_0 = predicted_durations_0.median()

# Predict the median survival durations for the upgraded backup (backup = 1)
predicted_durations_1 = aft_Weibull.predict_median(df_historic_fail_backup_upgrade)
median_survival_time_1 = predicted_durations_1.median()

# Step 3: Compare the median survival times
print("Median Survival Time (Backup = 0):", median_survival_time_0)
print("Median Survival Time (Backup = 1):", median_survival_time_1)
print("Difference in Median Survival Time:", median_survival_time_1 - median_survival_time_0)
# Out:
# Median Survival Time (Backup = 0): 82.55022630403245
# Median Survival Time (Backup = 1): 108.24220129295777
# Difference in Median Survival Time: 25.691974988925324

# %% [markdown]
# I dont think this median stuff is correct for either Servo or Backup. Max hour would be 48?

# %% [markdown]
# ### Comparing survival differences for the two upgrades

# %%
servo_cost = 150000
backup_cost = 100000

# Calculate the benefit per dollar for each upgrade type and add them as new columns
servo_time_diff_df['Servo Benefit per Dollar'] = servo_time_diff / servo_cost
backup_time_diff_df['Backup Benefit per Dollar'] = backup_time_diff / backup_cost
combined_df = pd.concat([servo_time_diff_df, backup_time_diff_df], axis=1)
combined_df.rename(columns={
    combined_df.columns[0]: 'time_servo', 
    combined_df.columns[1]: 'Servo Benefit per Dollar',
    combined_df.columns[2]: 'time_backup', 
    combined_df.columns[3]: 'Backup Benefit per Dollar'
}, inplace=True)
combined_df
# Out:
#      time_backup  Servo Benefit per Dollar  time_backup  \
# 402     6.321521                  0.000042     4.614908
# 355     6.321521                  0.000042     4.614908
# 403     6.321521                  0.000042     4.614908
# 389     5.216020                  0.000035     3.856285
# 341     4.083330                  0.000027     3.046444
# ..           ...                       ...          ...
# 331          NaN                       NaN     0.918250
# 323          NaN                       NaN     0.918250
# 373          NaN                       NaN     0.918250
# 408          NaN                       NaN     0.841748
# 410          NaN                       NaN     0.841748
#
#      Backup Benefit per Dollar
# 402                   0.000046
# 355                   0.000046
# 403                   0.000046
# 389                   0.000039
# 341                   0.000030
# ..                         ...
# 331                   0.000009
# 323                   0.000009
# ...

# %%
combined_df['Highest Benefit per Dollar'] = combined_df[['Servo Benefit per Dollar', 'Backup Benefit per Dollar']].max(axis=1)
combined_df['Source'] = np.where(combined_df['Highest Benefit per Dollar'] == combined_df['Servo Benefit per Dollar'], 'Servo', 'Backup')
combined_df_sorted = combined_df.sort_values(by='Highest Benefit per Dollar', ascending=False)
combined_df_sorted['Upgrade Cost'] = np.where(combined_df_sorted['Source'] == 'Servo', servo_cost, backup_cost)
# Add a column for the running total of the cost
combined_df_sorted['Running Total Cost'] = combined_df_sorted['Upgrade Cost'].cumsum()
combined_df_sorted
# Out:
#      time_backup  Servo Benefit per Dollar  time_backup  \
# 402     6.321521                  0.000042     4.614908
# 403     6.321521                  0.000042     4.614908
# 355     6.321521                  0.000042     4.614908
# 389     5.216020                  0.000035     3.856285
# 341     4.083330                  0.000027     3.046444
# ..           ...                       ...          ...
# 331          NaN                       NaN     0.918250
# 323          NaN                       NaN     0.918250
# 351     1.309444                  0.000009          NaN
# 408          NaN                       NaN     0.841748
# 410          NaN                       NaN     0.841748
#
#      Backup Benefit per Dollar  Highest Benefit per Dollar  Source  \
# 402                   0.000046                    0.000046  Backup
# 403                   0.000046                    0.000046  Backup
# 355                   0.000046                    0.000046  Backup
# ...

# %% [markdown]
# with a fixed budget of $2.5 million here are the upgrades we should be doing

# %%
combined_df_sorted[combined_df_sorted['Running Total Cost']<=2500000]
# Out:
#      time_backup  Servo Benefit per Dollar  time_backup  \
# 402     6.321521                  0.000042     4.614908
# 403     6.321521                  0.000042     4.614908
# 355     6.321521                  0.000042     4.614908
# 389     5.216020                  0.000035     3.856285
# 341     4.083330                  0.000027     3.046444
# 375     4.083330                  0.000027     3.046444
# 362     3.558173                  0.000024     2.663930
# 340     3.558173                  0.000024     2.663930
# 320     3.311061                  0.000022     2.482713
# 359     3.311061                  0.000022     2.482713
# 322          NaN                       NaN     2.418113
# 338     3.075339                  0.000021     2.309187
# 327     3.075339                  0.000021     2.309187
# 400     2.851483                  0.000019     2.143836
# 339     2.851483                  0.000019     2.143836
# 380     2.851483                  0.000019     2.143836
# ...
